# %%
import pandas as pd

# %%
data = pd.read_csv("crypto_data.csv")

# %%
data
# Out:
#                        id symbol                   name  current_price  \
# 0                 bitcoin    btc                Bitcoin   95839.000000
# 1                ethereum    eth               Ethereum    2687.540000
# 2                  ripple    xrp                    XRP       2.480000
# 3                  tether   usdt                 Tether       1.000000
# 4             binancecoin    bnb                    BNB     640.750000
# ..                    ...    ...                    ...            ...
# 95                story-2     ip                  Story       3.900000
# 96                    eos    eos                    EOS       0.615902
# 97                   gala   gala                   GALA       0.021197
# 98                  floki  floki                  FLOKI       0.000090
# 99  ethereum-name-service    ens  Ethereum Name Service      26.200000
#
#        market_cap  total_volume      high_24h       low_24h  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'symbol', 'name', 'current_price', 'market_cap', 'total_volume',
#        'high_24h', 'low_24h', 'timestamp'],
#       dtype='object')
